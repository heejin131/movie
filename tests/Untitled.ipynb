# %%
import pandas as pd

# %%
df_1 = pd.read_parquet("~/temp/movie/dt=20210101")
df_2 = pd.read_parquet("~/temp/movie")

# %%
df_1.head(1)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd     movieNm      openDt  \
# 0    1    1         0           OLD  20192567  원더 우먼 1984  2020-12-23
#
#     salesAmt salesShare salesInten salesChange    salesAcc audiCnt audiInten  \
# 0  274407080       51.4   41920830          18  3764838540   29884      2462
#
#   audiChange audiAcc scrnCnt showCnt
# 0          9  420870    1877    4329

# %%
df_2.head(1)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd     movieNm      openDt  \
# 0    1    1         0           OLD  20192567  원더 우먼 1984  2020-12-23
#
#     salesAmt salesShare salesInten salesChange    salesAcc audiCnt audiInten  \
# 0  274407080       51.4   41920830          18  3764838540   29884      2462
#
#   audiChange audiAcc scrnCnt showCnt        dt
# 0          9  420870    1877    4329  20210101

# %%
def test_save_df():
    ymd = "20210101"
    data = call_api(dt=ymd)
    df = list2df(data, ymd)
    base_path = "~/temp/movie"
    r = save_df(df, base_path)
    assert r == f"{base_path}/dt={ymd}"
    print("save_path", r)
    read_df = pd.read_parquet(r)
    assert 'dt' not in read_df.columns
    assert 'dt' in pd.read_parquet(base_path).columns

# %%
import pandas as pd
read_df = pd.read_parquet('/home/gmlwls5168/data/movies/dailyboxoffice/')
save_df = pd.read_parquet('/home/gmlwls5168/data/movies/merge/dailyboxoffice/dt=20240101')

# %%
len(read_df)
# Out:
# 200

# %%
len(save_df)
# Out:
# 98

# %%
read_df.tail(10)
# Out:
#      rnum  rank  rankInten rankOldAndNew   movieCd           movieNm  \
# 190     1     1          1           OLD  20212866             서울의 봄
# 191     2     2         -1           OLD  20203702        노량: 죽음의 바다
# 192     3     3          0           OLD  20234673  뽀로로 극장판 슈퍼스타 대모험
# 193     4     4          0           OLD  20235253           외계+인 2부
# 194     5     5          0           OLD  20190324            3일의 휴가
# 195     6     6          0           OLD  20235290         도티와 영원의 탑
# 196     7     7          0           OLD  20202247           싱글 인 서울
# 197     8     8          0           NEW  20235353           길위에 김대중
# 198     9     9         -1           OLD  20228560              너와 나
# 199    10    10          0           NEW  19580069                 돈
#
#          openDt   salesAmt  salesShare  salesInten  ...      salesAcc audiCnt  \
# 190  2023-11-22  428418007        47.1   -48679341  ...  119567912524   45359
# 191  2023-12-20  414890862        45.6   -79386896  ...   38492320604   44860
# 192  2023-12-13   27987535         3.1    -6354182  ...    3154801180    3051
# 193  2024-01-10   18369000         2.0   -14559000  ...      51297000    2041
# 194  2023-12-06    7230350         0.8    -1024150  ...    4892023659     895
# 195  2023-12-27    5516256         0.6    -2994403  ...     535186164     597
# 196  2023-11-29    2224489         0.2      988611  ...    3744915062     267
# 197  2024-01-10    1488000         0.2     1488000  ...     121277000     200
# 198  2023-10-25    1479456         0.2      352806  ...     333758409     162
# 199  1950-03-09     102000         0.0      102000  ...       2987000      51
#
#      audiInten  audiChange   audiAcc  scrnCnt  showCnt        dt multiMovieYn  \
# 190      -4807        -9.6  12280492     1291     4030  20240104          NaN
# 191      -8754       -16.3   3898314     1402     4111  20240104          NaN
# 192       -675       -18.1    344379      201      257  20240104          NaN
# 193      -1063       -34.2      5145        9        9  20240104          NaN
# 194        -99       -10.0    521358      102      120  20240104          NaN
# 195       -339       -36.2     57710       70       73  20240104          NaN
# 196        140       110.2    400282        7        9  20240104          NaN
# 197        200       100.0     13581        2        2  20240104          NaN
# 198         36        28.6     34215       12       14  20240104          NaN
# 199         51       100.0      1449        1        2  20240104          NaN
#
#     repNationCd
# 190           K
# 191           K
# 192           K
# 193           K
# 194           K
# 195           K
# 196           K
# 197           K
# 198           K
# 199           K
#
# [10 rows x 21 columns]
