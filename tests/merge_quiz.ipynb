# %%
import pandas as pd
import numpy as np
PATH = "~/data/movies/dailyboxoffice/dt=20240101"
df = pd.read_parquet(PATH)
#len(df)

#df.groupby(['multiMovieYn', 'repNationCd'], dropna=False, observed=False) \
#.size() \
#.reset_index(name='count')

# %%
# rankInten(전일대비 순위의 증감분을 출력) 은 사용하지 않음 drop 시킴
df = pd.read_parquet(PATH)
df_1 = df.drop(columns='rankInten')
df_1
# Out:
#     rnum  rank rankOldAndNew   movieCd                               movieNm  \
# 0      1     1           OLD  20203702                            노량: 죽음의 바다
# 1      2     2           OLD  20212866                                 서울의 봄
# 2      3     3           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 3      4     4           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 4      5     5           OLD  20235596                            트롤: 밴드 투게더
# 5      6     6           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 6      7     7           OLD  20235290                             도티와 영원의 탑
# 7      8     8           OLD  20234114                                    괴물
# 8      9     9           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 9     10    10           OLD  20235980                             말하고 싶은 비밀
# 10     1     1           OLD  20203702                            노량: 죽음의 바다
# ...

# %%
df3 = df_1.drop(columns=['rnum', 'rank', 'salesShare'])
df3
#unique_df = df3.drop_duplicates(subset='movieCd',keep='first')
#unique_df
# Out:
#    rankOldAndNew   movieCd                               movieNm      openDt  \
# 0            OLD  20203702                            노량: 죽음의 바다  2023-12-20
# 1            OLD  20212866                                 서울의 봄  2023-11-22
# 2            OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 3            OLD  20235735                          아쿠아맨과 로스트 킹덤  2023-12-20
# 4            OLD  20235596                            트롤: 밴드 투게더  2023-12-20
# 5            OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13
# 6            OLD  20235290                             도티와 영원의 탑  2023-12-27
# 7            OLD  20234114                                    괴물  2023-11-29
# 8            OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  2023-12-27
# 9            OLD  20235980                             말하고 싶은 비밀  2023-12-13
# 10           OLD  20203702                            노량: 죽음의 바다  2023-12-20
# ...

# %%
# movieCd 기준 unique 한 영화는 몇 편 인가요? 50편
df_u = df_1.drop_duplicates(subset='movieCd',keep='first')
df_u
#df_u.sort_values(by='movieNm', ascending=True)
# Out:
#    rnum rank rankOldAndNew   movieCd                               movieNm  \
# 0     1    1           OLD  20203702                            노량: 죽음의 바다
# 1     2    2           OLD  20212866                                 서울의 봄
# 2     3    3           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 3     4    4           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 4     5    5           OLD  20235596                            트롤: 밴드 투게더
# 5     6    6           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 6     7    7           OLD  20235290                             도티와 영원의 탑
# 7     8    8           OLD  20234114                                    괴물
# 8     9    9           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 9    10   10           OLD  20235980                             말하고 싶은 비밀
# 18    9    9           OLD  20190324                                3일의 휴가
# ...

# %%
# multiMovieYn, repNationCd 를 내부 참조하여 최대한 fill 했을 때

# 2-1. multiMovieYn 이 NaN 인 건수는? 5건
# 2-2. repNationCd 이 NaN 인 건수는? 5건
df_m = df_u[["movieNm","multiMovieYn"]].dropna(how='any')
df_r = df_u[["movieNm","repNationCd"]].dropna(how='any')
df_all = df_m.merge(df_r, how='outer',on='movieNm')
df_all
# 2-3. multiMovieYn 과 repNationCd 이 동시에 NaN 인 건수는? 0건 
#df_nan = df_m[(df_1["multiMovieYn"].isna()) & (df_1["repNationCd"].isna())]
# Out:
#                    movieNm multiMovieYn repNationCd
# 0                   3일의 휴가            N         NaN
# 1                교토에서 온 편지          NaN           K
# 2           그대들은 어떻게 살 것인가            Y         NaN
# 3                     나폴레옹            N         NaN
# 4                     너와 나          NaN           K
# 5            류이치 사카모토: 오퍼스            Y         NaN
# 6                리빙: 어떤 인생            Y         NaN
# 7                   립세의 사계            Y         NaN
# 8               사랑은 낙엽을 타고            Y         NaN
# 9                  싱글 인 서울          NaN           K
# 10                  어른 김장하          NaN           K
# 11  엔시티 네이션 : 투 더 월드 인 시네마          NaN           K
# 12                    쿼바디스            Y         NaN
# 13                    크레센도            Y         NaN
# 14               피아니스트의 전설            Y         NaN

# %%
# unique 한 영화목록의 audiCnt(관객수) 를 기준으로 rnum, rank 를 새로 생성하고 이때 head 3 와 tail 3 의 영화명은?
df_rnum = df_u.sort_values(by='audiCnt', ascending=False)
df_rnum
#df_u.assign(rank=audiCnt)
# Out:
#    rnum rank rankOldAndNew   movieCd                               movieNm  \
# 0     1    1           OLD  20203702                            노량: 죽음의 바다
# 1     2    2           OLD  20212866                                 서울의 봄
# 2     3    3           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 3     4    4           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 4     5    5           OLD  20235596                            트롤: 밴드 투게더
# 5     6    6           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 6     7    7           OLD  20235290                             도티와 영원의 탑
# 7     8    8           OLD  20234114                                    괴물
# 8     9    9           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 9    10   10           OLD  20235980                             말하고 싶은 비밀
# 18    9    9           OLD  20190324                                3일의 휴가
# ...
